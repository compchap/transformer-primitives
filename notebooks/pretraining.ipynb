# %% [markdown]
# # Where are we in the overall journey?

# %% [markdown]
# ![image.png](attachment:a1a01445-5c70-426b-a49d-ccc2bce93812.png)

# %% [markdown]
# # Here's what we will do in this chapter

# %% [markdown]
# ![image.png](attachment:c8fd6b8c-e904-4723-8a41-b9192f8d78d3.png)

# %% [markdown]
# # Setup LLM

# %% [markdown]
# ## Imports

# %%
import sys; sys.path.insert(0, "..")
import torch
import importlib
# importlib.reload(previous_chapters)
import previous_chapters

# %%
torch.__version__
# Out:
# '2.4.0'

# %%
torch.backends.mps.is_available()
# Out:
# True

# %%
from previous_chapters import GPTModel

# %% [markdown]
# ## Instantiating LLM

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,
    "context_length": 256,
    "emb_dim": 768,
    "n_heads": 12,
    "n_layers": 12, 
    "drop_rate": 0.1,
    "qkv_bias": False
}
torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.eval()
# Out:
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(256, 768)
#   (drop_emb): Dropout(p=0.1, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (1): TransformerBlock(
# ...

# %% [markdown]
# ## Implement Text Generation Process

# %%
import tiktoken
from previous_chapters import generate_text_simple

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)
    return tokenizer.decode(flat.tolist())

start_context = "Every effort moves you"
tokenizer = tiktoken.get_encoding("gpt2")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you rentingetic wasnم refres RexMeCHicular stren

# %% [markdown]
# ## Text Generation Loss

# %% [markdown]
# ### Conceptually how text generation or next token prediction works

# %% [markdown]
# ![image.png](attachment:da7e1cf0-cf2e-467c-bba6-774b09463532.png)

# %% [markdown]
# ### Text Generation

# %% [markdown]
# #### Step 1

# %%
inputs = torch.tensor([[16833, 3626, 6100],   # ["every effort moves",
                       [40,    1107, 588]])   #  "I really like"]

targets = torch.tensor([[3626, 6100, 345  ],  # [" effort moves you",
                        [1107, 588, 11311]])  #  " really like chocolate"]

# %% [markdown]
# #### Step 2

# %%
with torch.no_grad():
    logits = model(inputs)
probas = torch.softmax(logits, dim=-1)
print(probas.shape)
# batch, input_token_size, vocab_size
# Out:
# torch.Size([2, 3, 50257])

# %% [markdown]
# #### Step 3 and Step 4

# %%
token_ids = torch.argmax(probas, dim=-1, keepdim=True)
print("Token IDs:\n", token_ids)
# Out:
# Token IDs:
#  tensor([[[16657],
#          [  339],
#          [42826]],
#
#         [[49906],
#          [29669],
#          [41751]]])

# %% [markdown]
# #### Step 5

# %%
print(f"Targets batch 1: {token_ids_to_text(targets[0], tokenizer)}")
print(f"Outputs batch 1:"
      f" {token_ids_to_text(token_ids[0].flatten(), tokenizer)}")
# Out:
# Targets batch 1:  effort moves you
# Outputs batch 1:  Armed heNetflix

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# ![image.png](attachment:2c32ab9e-f4b2-4f2c-a233-ac81d920b2a8.png)

# %% [markdown]
# ## Calculate Softmax probabilyt of Input texts

# %%
text_idx = 0
target_probas_1 = probas[text_idx, [0, 1, 2], targets[text_idx]]
print("Text 1:", target_probas_1)

text_idx = 1
target_probas_2 = probas[text_idx, [0, 1, 2], targets[text_idx]]
print("Text 2:", target_probas_2)
# Out:
# Text 1: tensor([7.4541e-05, 3.1061e-05, 1.1563e-05])
# Text 2: tensor([1.0337e-05, 5.6776e-05, 4.7559e-06])

# %% [markdown]
# ## Calculate Cross Entropy (Negative Log Likelihood) - Manually

# %% [markdown]
# ![image.png](attachment:bbbe0ec6-62aa-42dd-adca-2dd71b4ba206.png)

# %%
cat = torch.cat((target_probas_1, target_probas_2))
print(cat)
log_probas = torch.log(cat)
print(log_probas)
# Out:
# tensor([7.4541e-05, 3.1061e-05, 1.1563e-05, 1.0337e-05, 5.6776e-05, 4.7559e-06])
# tensor([ -9.5042, -10.3796, -11.3677, -11.4798,  -9.7764, -12.2561])

# %%
avg_log_probas = torch.mean(log_probas)
print(avg_log_probas)
# Out:
# tensor(-10.7940)

# %%
neg_avg_log_probas = avg_log_probas * -1 # cross entropy loss
print(neg_avg_log_probas)
# Out:
# tensor(10.7940)

# %%
print("Logits shape:", logits.shape)
print("Targets shape:", targets.shape)
# Out:
# Logits shape: torch.Size([2, 3, 50257])
# Targets shape: torch.Size([2, 3])

# %%
logits_flat = logits.flatten(0, 1)
targets_flat = targets.flatten()
print("Flattened logits:", logits_flat.shape)
print("Flattened targets:", targets_flat.shape)
# Out:
# Flattened logits: torch.Size([6, 50257])
# Flattened targets: torch.Size([6])

# %% [markdown]
# ## Calculating Cross Entropy - Using PyTorch

# %%
loss = torch.nn.functional.cross_entropy(logits_flat, targets_flat)
print(loss)
# Out:
# tensor(10.7940)

# %%
perplexity = torch.exp(loss) # Measure of number of token in the vocab that are not considered during next work generation
perplexity
# Out:
# tensor(48725.8203)

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# ![image.png](attachment:dc4f9a85-eb01-44ed-a5ad-cc4c517132cc.png)

# %% [markdown]
# ## Load Dataset

# %%
file_path = "../data/the-verdict.txt"
with open(file_path, "r", encoding="utf-8") as file:
    text_data = file.read()

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))
print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 20479
# Tokens: 5145

# %% [markdown]
# ## Split Train and Validation Data

# %%
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]

# %%
from previous_chapters import create_dataloader_v1
torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)
val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %%
print("Train loader:")
for x, y in train_loader:
    print(x.shape, y.shape)

print("\nValidation loader:")
for x, y in val_loader:
    print(x.shape, y.shape)
# Out:
# Train loader:
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
#
# Validation loader:
# torch.Size([2, 256]) torch.Size([2, 256])

# %% [markdown]
# ## Utility functions to calculate the cross entropy loss

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch = input_batch.to(device)
    target_batch = target_batch.to(device)      
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(
        logits.flatten(0, 1), target_batch.flatten()
    )
    return loss

# %%
def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
device = torch.device('mps') if torch.backends.mps.is_available() else torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
with torch.no_grad():
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)
print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 10.98758347829183
# Validation loss: 10.98110580444336

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# ![image.png](attachment:140321f3-d746-4cd0-aa09-a5e5163a1b15.png)

# %% [markdown]
# # Training the LLM

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ![image.png](attachment:d7e80a1f-ef20-440d-b32c-f07ac596a725.png)

# %% [markdown]
# ## main function for pretraining LLMs

# %%
def train_model_simple(model, train_loader, val_loader,
                       optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    for epoch in range(num_epochs):
        model.train()
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad()
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            loss.backward()
            optimizer.step()
            tokens_seen += input_batch.numel()
            global_step += 1

            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, "
                      f"Val loss {val_loss:.3f}"
                )

        generate_and_print_sample(
            model, tokenizer, device, start_context
        )
    return train_losses, val_losses, track_tokens_seen

# %% [markdown]
# ### Utility Function

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(
            train_loader, model, device, num_batches=eval_iter
        )
        val_loss = calc_loss_loader(
            val_loader, model, device, num_batches=eval_iter
        )
    model.train()
    return train_loss, val_loss

# %%
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))
    model.train()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots(figsize=(5, 3))
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(
        epochs_seen, val_losses, linestyle="-.", label="Validation loss"
    )
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax2 = ax1.twiny()
    ax2.plot(tokens_seen, train_losses, alpha=0)
    ax2.set_xlabel("Tokens seen")
    fig.tight_layout()
    plt.show()

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 19
#      17     plt.show()
#      18 num_epochs = 5
# ---> 19 epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
#      20 plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)
#
# NameError: name 'train_losses' is not defined

# %% [markdown]
# ## Instantiating GPTModel Training Loop

# %%
torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(
     model.parameters(),
    lr=0.0004, weight_decay=0.1
)
num_epochs = 10
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="Every effort moves you", tokenizer=tokenizer
)
# Out:
# Ep 1 (Step 000000): Train loss 9.817, Val loss 9.924
# Ep 1 (Step 000005): Train loss 8.065, Val loss 8.332
# Every effort moves you,,,,,,,,,,,,.
# Ep 2 (Step 000010): Train loss 6.619, Val loss 7.042
# Ep 2 (Step 000015): Train loss 6.045, Val loss 6.596
# Every effort moves you, and,, and,, and,,,, and,.
# Ep 3 (Step 000020): Train loss 5.522, Val loss 6.510
# Ep 3 (Step 000025): Train loss 5.364, Val loss 6.379
# Every effort moves you, and to the of the of the picture. Gis.
# Ep 4 (Step 000030): Train loss 4.815, Val loss 6.261
# Ep 4 (Step 000035): Train loss 4.592, Val loss 6.288
# Every effort moves you of the "I the picture.                    "I"I the picture"I had the picture"I the picture and I had been the picture and
# Ep 5 (Step 000040): Train loss 3.869, Val loss 6.128
# ...

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# ![image.png](attachment:4194cda2-4e3f-44b5-961e-55f91e78fd71.png)

# %% [markdown]
# # Text Generation strategies to control Randomness
#
# we will cover text generation strategies for LLMs to reduce training data memorization and increase the originality of the LLM-generated text

# %% [markdown]
# ## Decoding Strategies to control Randomness

# %% [markdown]
# ### Putting Model to Evaluation Mode i.e Training = False

# %%
model.to(device)
model.eval()

# %%
tokenizer = tiktoken.get_encoding("gpt2")
token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(device),
    max_new_tokens=25,
    context_size=GPT_CONFIG_124M["context_length"]
)
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you?"
#
# "Yes--quite insensible to the irony. She wanted him vindicated--and by me!"

# %% [markdown]
# ### Temperature Scaling

# %%
vocab = { 
    "closer": 0,
    "every": 1, 
    "effort": 2, 
    "forward": 3,
    "inches": 4,
    "moves": 5, 
    "pizza": 6,
    "toward": 7,
    "you": 8,
} 
inverse_vocab = {v: k for k, v in vocab.items()}

# %%
# assume the LLM is given the start context "every effort moves you" and generates the following next-token logits:
next_token_logits = torch.tensor(
    [4.51, 0.89, -1.90, 6.75, 1.63, -1.62, -1.89, 6.28, 1.79]
)

# %%
probas = torch.softmax(next_token_logits, dim=0)
next_token_id = torch.argmax(probas).item()
# print("next_token_id: ", next_token_id)
print(inverse_vocab[next_token_id])
# Out:
# forward

# %%
# replacing argmax woth multinomial

torch.manual_seed(123) 
next_token_id = torch.multinomial(probas, num_samples=1).item()
print(inverse_vocab[next_token_id])
# Out:
# forward

# %%
def print_sampled_tokens(probas):
    torch.manual_seed(123)
    sample = [torch.multinomial(probas, num_samples=1).item()
             for i in range(1_000)]
    # sample = [torch.argmax(probas).item()
    #          for i in range(1_000)]
    sampled_ids = torch.bincount(torch.tensor(sample))
    for i, freq in enumerate(sampled_ids):
        print(f"{freq} x {inverse_vocab[i]}")

print_sampled_tokens(probas)
# Out:
# 73 x closer
# 0 x every
# 0 x effort
# 582 x forward
# 2 x inches
# 0 x moves
# 0 x pizza
# 343 x toward

# %%
def softmax_with_temperature(logits, temperature):
    scaled_logits = logits / temperature
    return torch.softmax(scaled_logits, dim=0)

# %%
temperatures = [1, 0.1, 5]
scaled_probas = [softmax_with_temperature(next_token_logits, T)
                for T in temperatures]
x = torch.arange(len(vocab))

bar_width = 0.15
fig, ax = plt.subplots(figsize=(5, 3))
for i, T in enumerate(temperatures):
    rects = ax.bar(x + i * bar_width, scaled_probas[i], 
                   bar_width, label=f'Temperature = {T}')
ax.set_ylabel('Probability')
ax.set_xticks(x)
ax.set_xticklabels(vocab.keys(), rotation=90)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Exercise 5.1
#
# Use the print_sampled_tokens function to print the sampling frequencies of the softmax probabilities scaled with the temperatures shown in figure 5.14. How often is the word pizza sampled in each case? Can you think of a faster and more accurate way to determine how often the word pizza is sampled?

# %%
import torch

vocab = { 
    "closer": 0,
    "every": 1, 
    "effort": 2, 
    "forward": 3,
    "inches": 4,
    "moves": 5, 
    "pizza": 6,
    "toward": 7,
    "you": 8,
} 
inverse_vocab = {v: k for k, v in vocab.items()}

next_token_logits = torch.tensor(
    [4.51, 0.89, -1.90, 6.75, 1.63, -1.62, -1.89, 6.28, 1.79]
)

def print_sampled_tokens(probas):
    torch.manual_seed(123)
    sample = [torch.multinomial(probas, num_samples=1).item() for i in range(1_000)]
    sampled_ids = torch.bincount(torch.tensor(sample))
    for i, freq in enumerate(sampled_ids):
        print(f"{freq} x {inverse_vocab[i]}")


def softmax_with_temperature(logits, temperature):
    scaled_logits = logits / temperature
    return torch.softmax(scaled_logits, dim=0)


temperatures = [1, 0.1, 5]  # Original, higher, and lower temperature
scaled_probas = [softmax_with_temperature(next_token_logits, T) for T in temperatures]

# %%
for i, probas in enumerate(scaled_probas):
    print("\n\nTemperature:", temperatures[i])
    print_sampled_tokens(probas)
# Out:
# Temperature: 1
# 73 x closer
# 0 x every
# 0 x effort
# 582 x forward
# 2 x inches
# 0 x moves
# 0 x pizza
# 343 x toward
#
#
# Temperature: 0.1
# 0 x closer
# 0 x every
# 0 x effort
# 985 x forward
# 0 x inches
# 0 x moves
# 0 x pizza
# 15 x toward
#
#
# Temperature: 5
# 165 x closer
# 75 x every
# 42 x effort
# 239 x forward
# 71 x inches
# 46 x moves
# 32 x pizza
# 227 x toward
# 103 x you

# %% [markdown]
# ### Top K sampling

# %% [markdown]
# #### Example

# %% [markdown]
# ![image.png](attachment:76377820-3242-49fa-9c46-46ffcef5a7d2.png)

# %% [markdown]
# #### APplying top-k

# %%
top_k = 3
top_logits, top_pos = torch.topk(next_token_logits, top_k)
print("Top logits:", top_logits)
print("Top positions:", top_pos)
# Out:
# Top logits: tensor([6.7500, 6.2800, 4.5100])
# Top positions: tensor([3, 7, 0])

# %% [markdown]
# #### Applying Masking

# %%
new_logits = torch.where(
    condition=next_token_logits < top_logits[-1],
    input=torch.tensor(float('-inf')),
    other=next_token_logits
)
print(new_logits)
# Out:
# tensor([4.5100,   -inf,   -inf, 6.7500,   -inf,   -inf,   -inf, 6.2800,   -inf])

# %% [markdown]
# #### Applying Softmax

# %%
topk_probas = torch.softmax(new_logits, dim=0)
print(topk_probas)
# Out:
# tensor([0.0615, 0.0000, 0.0000, 0.5775, 0.0000, 0.0000, 0.0000, 0.3610, 0.0000])

# %% [markdown]
# ### Modified Text Generation Function

# %%
def generate(model, idx, max_new_tokens, context_size,
             temperature=0.0, top_k=None, eos_id=None):
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]
        if top_k is not None:
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(
                logits < min_val,
                torch.tensor(float('-inf')).to(logits.device),
                logits
            )
        if temperature > 0.0:
            logits = logits / temperature
            probs = torch.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)
        if idx_next == eos_id:
            break
        idx = torch.cat((idx, idx_next), dim=1)
    return idx

# %%
torch.manual_seed(123)
token_ids = generate(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(device),
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.4
)
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you just," meant go furrowed by a laugh that lifted the tips so

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# ![image.png](attachment:f0819c68-10bd-4af9-8f0e-a14de1f4dbef.png)

# %% [markdown]
# # Loading And Saving Model weights

# %% [markdown]
# ## Saving the model

# %%
torch.save(model.state_dict(), "../saved-model/demo-saving-model.pth")

# %% [markdown]
# ## Loading a saved Model

# %%
model = GPTModel(GPT_CONFIG_124M)
model.load_state_dict(torch.load("../saved-model/demo-saving-model.pth", weights_only=True, map_location=device))
model.eval()

# %% [markdown]
# ## Saving the Model and Optimizer `state_dict`

# %%
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    }, 
    "../saved-model/model_and_optimizer.pth"
)

# %% [markdown]
# ## Loading Model and Optimizer states

# %%
checkpoint = torch.load("../saved-model/model_and_optimizer.pth", map_location=device, weights_only=True)
model = GPTModel(GPT_CONFIG_124M)
model.load_state_dict(checkpoint["model_state_dict"])
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=0.1)
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
model.train();

# %% [markdown]
# # Loading Pre-trained weights from OpenAI

# %% [markdown]
# ## Download a file from Github

# %%
import ssl
import urllib.request

def download_file(url, filename):
    # Create a custom SSL context that doesn't verify certificates
    ctx = ssl.create_default_context()
    ctx.check_hostname = False
    ctx.verify_mode = ssl.CERT_NONE

    # Use the custom context for the download
    with urllib.request.urlopen(url, context=ctx) as u, open(filename, 'wb') as f:
        f.write(u.read())

# Your existing URL and filename
url = (
    "https://raw.githubusercontent.com/rasbt/"
    "LLMs-from-scratch/main/ch05/"
    "01_main-chapter-code/gpt_download.py"
)
filename = url.split('/')[-1]

# Use the new function to download the file
download_file(url, filename)

print(f"File '{filename}' has been downloaded successfully.")
# Out:
# File 'gpt_download.py' has been downloaded successfully.

# %%
import importlib
from gpt_download import download_and_load_gpt2
settings, params = download_and_load_gpt2(
    model_size="124M", models_dir="gpt2"
)
# Out:
# checkpoint: 100%|██████████████████████████████████████████████████████████████████████████████████| 77.0/77.0 [00:00<00:00, 56.3kiB/s]
# encoder.json: 100%|██████████████████████████████████████████████████████████████████████████████| 1.04M/1.04M [00:00<00:00, 1.67MiB/s]
# hparams.json: 100%|████████████████████████████████████████████████████████████████████████████████| 90.0/90.0 [00:00<00:00, 29.6kiB/s]
# model.ckpt.data-00000-of-00001: 100%|██████████████████████████████████████████████████████████████| 498M/498M [03:09<00:00, 2.62MiB/s]
# model.ckpt.index: 100%|███████████████████████████████████████████████████████████████████████████| 5.21k/5.21k [00:00<00:00, 827kiB/s]
# model.ckpt.meta: 100%|██████████████████████████████████████████████████████████████████████████████| 471k/471k [00:00<00:00, 489kiB/s]
# vocab.bpe: 100%|███████████████████████████████████████████████████████████████████████████████████| 456k/456k [00:00<00:00, 1.88MiB/s]

# %%
print("Settings:", settings)
print("Parameter dictionary keys:", params.keys())
# Out:
# Settings: {'n_vocab': 50257, 'n_ctx': 1024, 'n_embd': 768, 'n_head': 12, 'n_layer': 12}
# Parameter dictionary keys: dict_keys(['blocks', 'b', 'g', 'wpe', 'wte'])

# %% [markdown]
# ### Description for above response
#
# ```
# 'blocks':
# This usually refers to the main transformer blocks or layers of the model. Each block typically contains self-attention mechanisms and feed-forward neural networks.
# 'b':
# This often stands for "bias". It could be a global bias term used in various parts of the model.
# 'g':
# This might represent a gain or scale factor, possibly used in layer normalization or other scaling operations within the model.
# 'wpe' (Word Position Embeddings):
# This typically refers to the weights for positional embeddings. These embeddings help the model understand the position of each token in the input sequence.
# 'wte' (Word Token Embeddings):
# This usually represents the weights for token embeddings. These embeddings convert input tokens (usually represented as integers) into dense vector representations.
# ```

# %%
print(params["wpe"])
print("Token embedding weight tensor dimensions:", params["wpe"].shape)
# Out:
# [[-1.8820720e-02 -1.9741860e-01  4.0267250e-03 ... -4.3043736e-02
#    2.8267192e-02  5.4490108e-02]
#  [ 2.3959434e-02 -5.3792033e-02 -9.4878644e-02 ...  3.4170013e-02
#    1.0171850e-02 -1.5572949e-04]
#  [ 4.2160717e-03 -8.4763914e-02  5.4514930e-02 ...  1.9744711e-02
#    1.9324856e-02 -2.1423856e-02]
#  ...
#  [-1.7986511e-03  1.6052092e-03 -5.5103153e-02 ...  1.3616630e-02
#   -7.1805264e-03  3.7552188e-03]
#  [ 3.2105497e-03  1.5500595e-03 -4.8944373e-02 ...  2.0725457e-02
#   -1.1837787e-02 -5.5682898e-04]
#  [ 2.6609693e-04  3.0272407e-03 -1.7086461e-03 ... -4.6505518e-03
#   -2.3541194e-03 -5.7855090e-03]]
# Token embedding weight tensor dimensions: (1024, 768)

# %% [markdown]
# ## Overall Architecture of a Model

# %% [markdown]
# ![image.png](attachment:d2f8dda8-532f-4add-b3e4-0c81557094bb.png)

# %% [markdown]
# ## Moving GPT-2 Weights to GPTModel (our local instance)

# %% [markdown]
# ### Create a dictionary of Model sizes

# %%
model_configs = {
    "gpt2-small (124M)": {"emb_dim": 768, "n_layers": 12, "n_heads": 12},
    "gpt2-medium (355M)": {"emb_dim": 1024, "n_layers": 24, "n_heads": 16},
    "gpt2-large (774M)": {"emb_dim": 1280, "n_layers": 36, "n_heads": 20},
    "gpt2-xl (1558M)": {"emb_dim": 1600, "n_layers": 48, "n_heads": 25},
}

# %% [markdown]
# ### Loading the smallest Model

# %%
model_name = "gpt2-small (124M)"
NEW_CONFIG = GPT_CONFIG_124M.copy()
NEW_CONFIG.update(model_configs[model_name])

# %%
NEW_CONFIG.update({"context_length": 1024})

# %%
NEW_CONFIG.update({"qkv_bias": True})

# %%
gpt = GPTModel(NEW_CONFIG)
gpt.eval()
# Out:
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.1, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (1): TransformerBlock(
# ...

# %%
def assign(left, right):
    if left.shape != right.shape:
        raise ValueError(f"Shape mismatch. Left: {left.shape}, "
                          "Right: {right.shape}"
        )
    return torch.nn.Parameter(torch.tensor(right))

# %%
import numpy as np

def load_weights_into_gpt(gpt, params):
    gpt.pos_emb.weight = assign(gpt.pos_emb.weight, params['wpe'])
    gpt.tok_emb.weight = assign(gpt.tok_emb.weight, params['wte'])

    for b in range(len(params["blocks"])):
        # weight
        q_w, k_w, v_w = np.split(
            (params["blocks"][b]["attn"]["c_attn"])["w"], 3, axis=-1)
        gpt.trf_blocks[b].att.W_query.weight = assign(
            gpt.trf_blocks[b].att.W_query.weight, q_w.T)
        gpt.trf_blocks[b].att.W_key.weight = assign(
            gpt.trf_blocks[b].att.W_key.weight, k_w.T)
        gpt.trf_blocks[b].att.W_value.weight = assign(
            gpt.trf_blocks[b].att.W_value.weight, v_w.T)

        # Bias
        q_b, k_b, v_b = np.split(
            (params["blocks"][b]["attn"]["c_attn"])["b"], 3, axis=-1)
        gpt.trf_blocks[b].att.W_query.bias = assign(
            gpt.trf_blocks[b].att.W_query.bias, q_b)
        gpt.trf_blocks[b].att.W_key.bias = assign(
            gpt.trf_blocks[b].att.W_key.bias, k_b)
        gpt.trf_blocks[b].att.W_value.bias = assign(
            gpt.trf_blocks[b].att.W_value.bias, v_b)

        # output projection
        gpt.trf_blocks[b].att.out_proj.weight = assign(
            gpt.trf_blocks[b].att.out_proj.weight, 
            params["blocks"][b]["attn"]["c_proj"]["w"].T)
        gpt.trf_blocks[b].att.out_proj.bias = assign(
            gpt.trf_blocks[b].att.out_proj.bias, 
            params["blocks"][b]["attn"]["c_proj"]["b"])

        # feedforward layer
        gpt.trf_blocks[b].ff.layers[0].weight = assign(
            gpt.trf_blocks[b].ff.layers[0].weight, 
            params["blocks"][b]["mlp"]["c_fc"]["w"].T)
        gpt.trf_blocks[b].ff.layers[0].bias = assign(
            gpt.trf_blocks[b].ff.layers[0].bias, 
            params["blocks"][b]["mlp"]["c_fc"]["b"])
        
        gpt.trf_blocks[b].ff.layers[2].weight = assign(
            gpt.trf_blocks[b].ff.layers[2].weight, 
            params["blocks"][b]["mlp"]["c_proj"]["w"].T)
        gpt.trf_blocks[b].ff.layers[2].bias = assign(
            gpt.trf_blocks[b].ff.layers[2].bias, 
            params["blocks"][b]["mlp"]["c_proj"]["b"])

        # Normalization Layers - 1 & 2
        gpt.trf_blocks[b].norm1.scale = assign(
            gpt.trf_blocks[b].norm1.scale, 
            params["blocks"][b]["ln_1"]["g"])
        gpt.trf_blocks[b].norm1.shift = assign(
            gpt.trf_blocks[b].norm1.shift, 
            params["blocks"][b]["ln_1"]["b"])
        
        gpt.trf_blocks[b].norm2.scale = assign(
            gpt.trf_blocks[b].norm2.scale, 
            params["blocks"][b]["ln_2"]["g"])
        gpt.trf_blocks[b].norm2.shift = assign(
            gpt.trf_blocks[b].norm2.shift, 
            params["blocks"][b]["ln_2"]["b"])

    gpt.final_norm.scale = assign(gpt.final_norm.scale, params["g"])
    gpt.final_norm.shift = assign(gpt.final_norm.shift, params["b"])
    gpt.out_head.weight = assign(gpt.out_head.weight, params["wte"])

# %%
device = torch.device('mps') if torch.backends.mps.is_available() else torch.device("cuda" if torch.cuda.is_available() else "cpu")
load_weights_into_gpt(gpt, params)
gpt.to(device)
# Out:
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.1, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_shortcut): Dropout(p=0.1, inplace=False)
#     )
#     (1): TransformerBlock(
# ...

# %%
torch.manual_seed(123)
token_ids = generate(
    model=gpt,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(device),
    max_new_tokens=30,
    context_size=NEW_CONFIG["context_length"],
    top_k=50,
    temperature=1.5
)
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you toward more efficient and efficient processes, like in the car's oil and gas operation," the study said. To see if that leads to greater benefit from

# %%
train_loss = calc_loss_loader(train_loader, gpt, device)
train_loss
# Out:
# 3.7547629144456653

# %%
val_loss = calc_loss_loader(val_loader, gpt, device)
val_loss
# Out:
# 3.559633731842041
